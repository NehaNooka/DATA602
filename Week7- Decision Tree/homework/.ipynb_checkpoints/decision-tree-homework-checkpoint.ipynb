# %% [markdown]
# # Week7 - Tree Assignment
#
# - Load the breast cancer dataset using datasets.load_breast_cancer()
# - Use scatter plots to look at the data (use different colors for the classes)
# - Use box plots to look at the data
# - create a training and test set with random_state = 3
# - train a decision tree model on the training set.
# - train a logistic regression model on the training set
# - train a random forest model on the training set
# - Which model performed better?
# - Which features were most relevant in each model (a part from random forest)?
# - Use grid search to improve performance on the best performed model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.datasets import load_breast_cancer
df = load_breast_cancer()
dfX = df['data']
dfy = df['target']
dfNames = df['feature_names']

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.DataFrame(df.data, columns=[df.feature_names])
data = data.assign(target=pd.Series(df.target))
data.head()
# Out:
#   mean radius mean texture mean perimeter mean area mean smoothness  \
# 0       17.99        10.38         122.80    1001.0         0.11840
# 1       20.57        17.77         132.90    1326.0         0.08474
# 2       19.69        21.25         130.00    1203.0         0.10960
# 3       11.42        20.38          77.58     386.1         0.14250
# 4       20.29        14.34         135.10    1297.0         0.10030
#
#   mean compactness mean concavity mean concave points mean symmetry  \
# 0          0.27760         0.3001             0.14710        0.2419
# 1          0.07864         0.0869             0.07017        0.1812
# 2          0.15990         0.1974             0.12790        0.2069
# 3          0.28390         0.2414             0.10520        0.2597
# 4          0.13280         0.1980             0.10430        0.1809
#
#   mean fractal dimension  ... worst texture worst perimeter worst area  \
# 0                0.07871  ...         17.33          184.60     2019.0
# ...

# %%
dfNames
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
plt.scatter(
    x=data['mean radius'],
    y=data['mean texture'],
    c= data ['target']
    )
plt.show()

# %%
plt.scatter(
    x=data['mean area'],
    y=data['mean perimeter'],
    c= data ['target']
    )
plt.show()

# %%
plt.scatter(
    x=data['mean concave points'],
    y=data['worst concave points'],
    c= data ['target']
    )
plt.show()

# %%
plt.scatter(
    x=data['mean fractal dimension'],
    y=data['worst fractal dimension'],
    c= data ['target']
    )
plt.show()

# %%
plt.scatter(
    x=data['worst concave points'],
    y=data['worst area'],
    c= data ['target']
    )
plt.show()

# %%
plt.scatter(
    x=data['worst perimeter'],
    y=data['worst radius'],
    c= data ['target']
    )
plt.show()

# %%
plt.scatter(
    x=data['mean concave points'],
    y=data['worst radius'],
    c= data ['target']
    )
plt.show()

# %%
plt.scatter(
    x=data['mean concavity'],
    y=data['worst concavity'],
    c= data ['target']
    )
plt.show()

# %%
plt.scatter(
    x=data['area error'],
    y=data['mean radius'],
    c= data ['target']
    )
plt.show()

# %%
plot=data.boxplot(grid=False, rot=45, fontsize=12, figsize=(20,10))

# %%
from sklearn.model_selection import train_test_split
y = data['target']
X = data[[x for x in data.columns if x != 'target']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# %%
X_train.drop(['target'],axis=1,inplace=True)
X_test.drop(['target'],axis=1,inplace=True)

# %% [markdown]
# ## Using Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

tree_model = DecisionTreeClassifier(criterion='gini', random_state=1)
model1=tree_model.fit(X_train, y_train)

from sklearn import tree

plt.figure(figsize=(20,10))
tree.plot_tree(tree_model, feature_names=dfNames, fontsize=10)
plt.show()

# %%
print(f'Test accuracy using Decision Tree is: {model1.score(X_test, y_test):.2f}')
# Out:
# Test accuracy using Decision Tree is: 0.90

# %% [markdown]
# ## Using Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logisticModel= LogisticRegression()
model2=logisticModel.fit(X_train, y_train)

# %%
print(f'Test accuracy using Logistic Regression is : {model2.score(X_test, y_test):.2f}')
# Out:
# Test accuracy using Logistic Regression is : 0.91

# %% [markdown]
# ## Using Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rnd_clf = RandomForestClassifier(n_estimators=500)
model3=rnd_clf.fit(X_train, y_train)

# %%
print(f'Test accuracy using Random Forest is : {model3.score(X_test, y_test):.2f}')
# Out:
# Test accuracy using Random Forest is : 0.93

# %% [markdown]
# ## Feature Importances

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

imps = list(zip(df.feature_names, rnd_clf.feature_importances_))

fi = pd.Series([x[1] for x in imps], index=[x[0] for x in imps])
fi = fi.sort_values(ascending=True)

fi.plot.barh()
plt.title('Feature Importances', loc='left')
plt.show()

# %% [markdown]
# ## Random Forest performed best among all, so using Grid Search on it to perform better

# %%
from sklearn.model_selection import GridSearchCV
params =  {'class_weight': [None, 'balanced'], 'C':[0.01, 0.1, 1, 10, 100],'max_iter':[1,100,1000,2000],
          'penalty':['l1', 'l2', 'elasticnet', 'none']}
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=logisticModel,
                           param_grid=params,
                           cv = 4,
                           n_jobs=-1, verbose=1, scoring="accuracy")
grid_search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 160 candidates, totalling 640 fits
# /Users/nehanooka/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/nehanooka/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# /Users/nehanooka/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/nehanooka/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...

# %%
print(f'Test accuracy using Grid Search with Logistic Reg : {grid_search.score(X_test, y_test):.2f}')
# Out:
# Test accuracy using Grid Search with Logistic Reg : 0.94

# %% [markdown]
# ## There is not much improve in performance after using Grid Search. The accuracy increased from 93 to 94.
